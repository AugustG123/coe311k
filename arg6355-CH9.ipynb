# %%
import numpy as np
import matplotlib.pyplot as plt

# Data points 

X = np.array([1, 2, 3, 4, 5])

Y = np.array([1.2, 2.8, 3.6, 4.5, 5.1])

# Stack the design matrix with a column of ones (for the intercept)

A = np.vstack([X, np.ones(len(X))]).T

# Solve using least squares

m, c = np.linalg.lstsq(A, Y, rcond=None)[0]

print(f"Slope: {m}, Intercept: {c}")

plt.plot(Y,X)
x1 = np.linspace(1,5,20)
y1 = x1*m+c
plt.plot(y1,x1)
# Out:
# Slope: 0.9500000000000001, Intercept: 0.5900000000000001

# %%
X = np.random.rand(5)
Y = np.random.rand(5)

A = np.vstack([X, np.ones(len(X))]).T
m, c = np.linalg.lstsq(A, Y, rcond=None)[0]

print(f"Slope: {m}, Intercept: {c}")

plt.plot(Y,X)
x1 = np.linspace(0,1,20)
y1 = x1*m + c
plt.plot(x1,y1)
#It fits terribly
# Out:
# Slope: -0.6067794257851336, Intercept: 0.9712282546219785

# %%
X = np.linspace(0,1,100)
y = []
rng = np.random.default_rng()

for value in x:
    y.append(value*5+2 + rng.random())
Y = np.array(y)

A = np.vstack([X, np.ones(len(X))]).T
m, c = np.linalg.lstsq(A, Y, rcond=None)[0]

print(f"Slope: {m}, Intercept: {c}")

plt.plot(Y,X)

y1 = m*
# Out:
# Slope: 5.024513795900931, Intercept: 2.4882899439728376
