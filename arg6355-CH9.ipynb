# %%
import numpy as np
import matplotlib.pyplot as plt

# Data points 

X = np.array([1, 2, 3, 4, 5])

Y = np.array([1.2, 2.8, 3.6, 4.5, 5.1])

# Stack the design matrix with a column of ones (for the intercept)

A = np.vstack([X, np.ones(len(X))]).T

# Solve using least squares

m, c = np.linalg.lstsq(A, Y, rcond=None)[0]

print(f"Slope: {m}, Intercept: {c}")

plt.scatter(Y,X)
x1 = np.linspace(1,5,20)
y1 = x1*m+c
plt.plot(y1,x1)
# Out:
# Slope: 0.9500000000000001, Intercept: 0.5900000000000001

# %%
X = np.random.rand(5)
Y = np.random.rand(5)

A = np.vstack([X, np.ones(len(X))]).T
m, c = np.linalg.lstsq(A, Y, rcond=None)[0]

print(f"Slope: {m}, Intercept: {c}")

plt.scatter(Y,X)
x1 = np.linspace(0,1,20)
y1 = x1*m + c
plt.plot(x1,y1)
#It fits terribly
# Out:
# Slope: -0.30872331516262963, Intercept: 0.5382234903008125

# %%
X = np.linspace(0,1,100)
y = []
rng = np.random.default_rng()

for value in x:
    y.append(value*5+2 + rng.random())
Y = np.array(y)

A = np.vstack([X, np.ones(len(X))]).T
m, c = np.linalg.lstsq(A, Y, rcond=None)[0]

print(f"Slope: {m}, Intercept: {c}")

plt.scatter(X,Y)

y1 = m*X+c
plt.plot(X,y1)
# Out:
# Slope: 4.927415049415615, Intercept: 2.517942789493234

# %%
degree = 2 # Degree of the polynomial
coefficients = np.polyfit(X, Y, degree)
print("Polynomial Coefficients: ", coefficients)
polynomial = np.poly1d(coefficients)
# Out:
# Polynomial Coefficients:  [-0.16019858  5.08761363  2.49151272]

# %%
y_pred = polynomial(X)
plt.scatter(X, Y, color='blue', label='Data points') # Original data points
plt.plot(X, y_pred, color='red', label=f'Polynomial fit of degree {degree}')
# Fitted curve
plt.title('Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %%
print(f'Poly')
mse = np.mean((Y - y_pred)**2)
print(f'Mean Squared Error: {mse:.4f}')

ss_total = np.sum((Y - np.mean(y))**2)
ss_res = np.sum((Y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared:.4f}')

y_pred = X*m+c
print(f'Linear')
mse = np.mean((Y - y_pred)**2)
print(f'Mean Squared Error: {mse:.4f}')

ss_total = np.sum((Y - np.mean(y))**2)
ss_res = np.sum((Y - y_pred)**2)
r_squared = 1 - (ss_res / ss_total)
print(f'R-squared: {r_squared:.4f}')
# Out:
# Poly
# Mean Squared Error: 0.0839
# R-squared: 0.9609
# Linear
# Mean Squared Error: 0.0839
# R-squared: 0.9609
